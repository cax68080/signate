# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("./train.csv")
df_train_on = df_train[df_train["target"] == 1]
df_train_off = df_train[df_train["target"] == 0]
display(df_train.head())
display(df_train_on.head())
display(df_train_off.head())
# Out:
#    id  age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   0   56        1                      5882         0                 38
# 1   3   50        0                      1767         1                 35
# 2   7   41        0                       250         1                 30
# 3  11   47        0                       582         1                 20
# 4  12   60        0                        80         0                 25
#
#    high_blood_pressure    platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  185315.0104          0.844417           134    1
# 1                    0  371620.3666          0.837448           136    0
# 2                    0  372810.2084          0.819996           139    1
# 3                    0  185780.6482          0.870314           137    0
# 4                    0  265096.3999          0.828112           136    1
#
#    smoking  time  target
# 0        0    10       1
# 1        0   187       1
# 2        0    29       1
# 3        0    43       0
# 4        0   213       0
#    id  age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   0   56        1                      5882         0                 38
# 1   3   50        0                      1767         1                 35
# 2   7   41        0                       250         1                 30
# 5  20   80        0                        60         1                 50
# 7  23   58        0                       103         0                 45
#
#    high_blood_pressure    platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  185315.0104          0.844417           134    1
# 1                    0  371620.3666          0.837448           136    0
# 2                    0  372810.2084          0.819996           139    1
# 5                    1  198578.9451          1.005423           143    1
# 7                    0  164019.0477          0.915698           136    1
#
#    smoking  time  target
# 0        0    10       1
# 1        0   187       1
# 2        0    29       1
# 5        0    33       1
# 7        1   210       1
#     id  age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 3   11   47        0                       582         1                 20
# 4   12   60        0                        80         0                 25
# 6   21   67        0                       582         0                 35
# 9   25   61        0                        80         0                 25
# 10  26   77        1                       553         1                 50
#
#     high_blood_pressure    platelets  serum_creatinine  serum_sodium  sex  \
# 3                     0  185780.6482          0.870314           137    0
# 4                     0  265096.3999          0.828112           136    1
# 6                     1  268027.6685          0.752896           134    0
# 9                     0  263893.6535          0.829171           136    1
# 10                    0  258656.0382          0.882218           140    1
#
#     smoking  time  target
# 3         0    43       0
# 4         0   213       0
# 6         0   207       0
# 9         0   213       0
# 10        0   209       0

# %%
display(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1000 non-null   int64
#  1   age                       1000 non-null   int64
#  2   anaemia                   1000 non-null   int64
#  3   creatinine_phosphokinase  1000 non-null   int64
#  4   diabetes                  1000 non-null   int64
#  5   ejection_fraction         1000 non-null   int64
#  6   high_blood_pressure       1000 non-null   int64
#  7   platelets                 1000 non-null   float64
#  8   serum_creatinine          1000 non-null   float64
#  9   serum_sodium              1000 non-null   int64
#  10  sex                       1000 non-null   int64
#  11  smoking                   1000 non-null   int64
#  12  time                      1000 non-null   int64
#  13  target                    1000 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 109.5 KB
# None

# %%
print(df_train.shape)
print(df_train_off.shape)
print(df_train_on.shape)
# Out:
# (1000, 14)
# (802, 14)
# (198, 14)

# %%
display(df_train.corr())
# Out:
#                                 id       age   anaemia  \
# id                        1.000000 -0.009706  0.047117
# age                      -0.009706  1.000000 -0.081584
# anaemia                   0.047117 -0.081584  1.000000
# creatinine_phosphokinase -0.032510  0.073761 -0.060977
# diabetes                 -0.016481 -0.292931  0.126494
# ejection_fraction        -0.002869  0.167132  0.223001
# high_blood_pressure       0.010901  0.049607 -0.026679
# platelets                 0.076857 -0.132735  0.121458
# serum_creatinine         -0.029488  0.018757  0.014769
# serum_sodium             -0.054380  0.086147  0.181867
# sex                       0.036229  0.037417 -0.179634
# smoking                  -0.024793 -0.024095 -0.174311
# time                     -0.005215 -0.037797 -0.011305
# target                    0.028046  0.115899 -0.032421
#
#                           creatinine_phosphokinase  diabetes  \
# id                                       -0.032510 -0.016481
# age                                       0.073761 -0.292931
# anaemia                                  -0.060977  0.126494
# creatinine_phosphokinase                  1.000000 -0.069392
# diabetes                                 -0.069392  1.000000
# ejection_fraction                        -0.009976  0.051338
# high_blood_pressure                       0.021842  0.047725
# platelets                                -0.093147  0.074693
# serum_creatinine                          0.071342 -0.045613
# serum_sodium                              0.042080 -0.113858
# sex                                      -0.012281 -0.072535
# smoking                                   0.010973 -0.119327
# time                                     -0.093119  0.020410
# target                                    0.122632  0.031315
#
#                           ejection_fraction  high_blood_pressure  platelets  \
# id                                -0.002869             0.010901   0.076857
# age                                0.167132             0.049607  -0.132735
# anaemia                            0.223001            -0.026679   0.121458
# creatinine_phosphokinase          -0.009976             0.021842  -0.093147
# diabetes                           0.051338             0.047725   0.074693
# ejection_fraction                  1.000000             0.082760   0.021659
# high_blood_pressure                0.082760             1.000000   0.014334
# platelets                          0.021659             0.014334   1.000000
# serum_creatinine                   0.063066            -0.019452  -0.107409
# serum_sodium                       0.103852            -0.051340  -0.021707
# sex                               -0.152956             0.027694  -0.111318
# smoking                            0.014769             0.141865  -0.004204
# time                              -0.101403            -0.096224   0.060992
# target                            -0.026801             0.147968  -0.055184
#
#                           serum_creatinine  serum_sodium       sex   smoking  \
# id                               -0.029488     -0.054380  0.036229 -0.024793
# age                               0.018757      0.086147  0.037417 -0.024095
# anaemia                           0.014769      0.181867 -0.179634 -0.174311
# creatinine_phosphokinase          0.071342      0.042080 -0.012281  0.010973
# diabetes                         -0.045613     -0.113858 -0.072535 -0.119327
# ejection_fraction                 0.063066      0.103852 -0.152956  0.014769
# high_blood_pressure              -0.019452     -0.051340  0.027694  0.141865
# platelets                        -0.107409     -0.021707 -0.111318 -0.004204
# serum_creatinine                  1.000000     -0.097223 -0.040661 -0.054871
# serum_sodium                     -0.097223      1.000000 -0.064175  0.002493
# sex                              -0.040661     -0.064175  1.000000  0.334151
# smoking                          -0.054871      0.002493  0.334151  1.000000
# time                             -0.154102     -0.032669 -0.009283 -0.051916
# target                            0.221103     -0.091057 -0.037868 -0.107457
#
#                               time    target
# id                       -0.005215  0.028046
# age                      -0.037797  0.115899
# anaemia                  -0.011305 -0.032421
# creatinine_phosphokinase -0.093119  0.122632
# diabetes                  0.020410  0.031315
# ejection_fraction        -0.101403 -0.026801
# high_blood_pressure      -0.096224  0.147968
# platelets                 0.060992 -0.055184
# serum_creatinine         -0.154102  0.221103
# serum_sodium             -0.032669 -0.091057
# sex                      -0.009283 -0.037868
# smoking                  -0.051916 -0.107457
# time                      1.000000 -0.152785
# target                   -0.152785  1.000000

# %%
display(df_train.describe())
# Out:
#                 id          age     anaemia  creatinine_phosphokinase  \
# count  1000.000000  1000.000000  1000.00000               1000.000000
# mean    999.734000    57.632000     0.41600                605.359000
# std     578.002214     9.875328     0.49314                971.937382
# min       0.000000    39.000000     0.00000                 23.000000
# 25%     496.750000    50.000000     0.00000                 93.000000
# 50%    1007.500000    58.000000     0.00000                255.000000
# 75%    1512.250000    61.000000     1.00000                582.000000
# max    1998.000000    85.000000     1.00000               7861.000000
#
#           diabetes  ejection_fraction  high_blood_pressure      platelets  \
# count  1000.000000        1000.000000          1000.000000    1000.000000
# mean      0.270000          36.691000             0.237000  278330.242337
# std       0.444182          11.037089             0.425455   79543.675235
# min       0.000000          14.000000             0.000000  138173.134500
# 25%       0.000000          30.000000             0.000000  256629.434900
# 50%       0.000000          35.000000             0.000000  267025.054700
# 75%       1.000000          40.000000             0.000000  279943.418975
# max       1.000000          70.000000             1.000000  824131.916700
#
#        serum_creatinine  serum_sodium          sex     smoking         time  \
# count       1000.000000   1000.000000  1000.000000  1000.00000  1000.000000
# mean           1.030258    136.841000     0.755000     0.25600   149.560000
# std            0.704616      3.405777     0.430302     0.43664    77.381072
# min            0.629178    116.000000     0.000000     0.00000     4.000000
# 25%            0.798218    135.000000     1.000000     0.00000    84.500000
# 50%            0.844389    136.500000     1.000000     0.00000   185.000000
# 75%            0.956294    139.000000     1.000000     1.00000   213.000000
# max            8.994597    146.000000     1.000000     1.00000   285.000000
#
#             target
# count  1000.000000
# mean      0.198000
# std       0.398692
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
plt.style.use("seaborn-white")
#plt.hist(df_train["age"])
plt.hist(df_train_off["age"])
plt.hist(df_train_on["age"])
# Out:
# (array([26., 30., 12., 34., 12., 22., 28.,  5., 21.,  8.]),
#  array([41. , 45.4, 49.8, 54.2, 58.6, 63. , 67.4, 71.8, 76.2, 80.6, 85. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.use("seaborn-white")
#plt.hist(df_train["time"])
plt.hist(df_train_on["time"])
#plt.hist(df_train_off["time"])
# Out:
# (array([40., 15., 26., 22., 11.,  3., 19., 46., 13.,  3.]),
#  array([ 10. ,  36.8,  63.6,  90.4, 117.2, 144. , 170.8, 197.6, 224.4,
#         251.2, 278. ]),
#  <BarContainer object of 10 artists>)

# %%
print(pd.value_counts(df_train["sex"]))
print(pd.value_counts(df_train["smoking"]))
# Out:
# 1    755
# 0    245
# Name: sex, dtype: int64
# 0    744
# 1    256
# Name: smoking, dtype: int64
# 213    123
# 215     47
# 214     42
# 187     39
# 209     34
#       ...
# 111      1
# 192      1
# 148      1
# 45       1
# 42       1
# Name: time, Length: 110, dtype: int64
