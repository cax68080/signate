# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
df_train = pd.read_csv("./train.tsv",sep="\t")
df_test = pd.read_csv("./test.tsv",sep="\t")
df_result = pd.read_csv("./sample_submit.csv",sep="\t",header=None)
display(df_train.head())
display(df_test.head())
display(df_result.head())
# Out:
#    Unnamed: 0   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0           0  39.4          4          85.0         70    2070          18.6
# 1           3  18.0          6         171.0         97    2984          14.5
# 2           9  32.7          6         168.0        132    2910          11.4
# 3          11  38.1          4          89.0         60    1968          18.8
# 4          13  28.0          4          98.0         80    2164          15.0
#
#    model year  origin               car name
# 0          78       3         datsun b210 gx
# 1          75       1             ford pinto
# 2          80       3          datsun 280-zx
# 3          80       3  toyota corolla tercel
# 4          72       1        dodge colt (sw)
#    Unnamed: 0  cylinders  displacement horsepower  weight  acceleration  \
# 0           1          8         350.0        180    4499          12.5
# 1           2          4         156.0        105    2745          16.7
# 2           4          6         156.0        108    2930          15.5
# 3           5          4         108.0         70    2245          16.9
# 4           6          4         105.0         63    2125          14.7
#
#    model year  origin                  car name
# 0          73       1  oldsmobile vista cruiser
# 1          78       1          plymouth sapporo
# 2          76       3            toyota mark ii
# 3          82       3            toyota corolla
# 4          82       1    plymouth horizon miser
#       0
# 0  1,11
# 1  2,25
# 2  4,24
# 3  5,33
# 4  6,32

# %%
df_train.shape
# Out:
# (199, 10)

# %%
df_test.shape
# Out:
# (199, 9)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    199 non-null    int64
#  1   mpg           199 non-null    float64
#  2   cylinders     199 non-null    int64
#  3   displacement  199 non-null    float64
#  4   horsepower    199 non-null    object
#  5   weight        199 non-null    int64
#  6   acceleration  199 non-null    float64
#  7   model year    199 non-null    int64
#  8   origin        199 non-null    int64
#  9   car name      199 non-null    object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 15.7+ KB

# %%
df_train[["horsepower"]].dtypes
# Out:
# horsepower    object
# dtype: object

# %%
# 数値ではない型の要素の抽出
df_train[df_train["horsepower"].apply(lambda s:pd.to_numeric(s, errors='coerce')).isnull()]
# Out:
#      Unnamed: 0   mpg  cylinders  displacement horsepower  weight  \
# 25           50  40.9          4          85.0          ?    1835
# 80          166  34.5          4         100.0          ?    2320
# 176         351  23.6          4         140.0          ?    2905
#
#      acceleration  model year  origin              car name
# 25           17.3          80       2  renault lecar deluxe
# 80           15.8          81       2           renault 18i
# 176          14.3          80       1    ford mustang cobra

# %%
df_train_wk = df_train.drop([25,80,176])
df_train_wk.shape
df_train_wk["horsepower"] = df_train_wk["horsepower"].astype("float64")
df_train_wk.dtypes
# Out:
# Unnamed: 0        int64
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
hp_mean = df_train_wk["horsepower"].mean()
print(hp_mean)
# Out:
# 107.25

# %%
df_train[df_train["horsepower"].apply(lambda s:pd.to_numeric(s, errors='coerce')).isnull()]
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 25           50  40.9          4          85.0         NaN    1835
# 80          166  34.5          4         100.0         NaN    2320
# 176         351  23.6          4         140.0         NaN    2905
#
#      acceleration  model year  origin              car name
# 25           17.3          80       2  renault lecar deluxe
# 80           15.8          81       2           renault 18i
# 176          14.3          80       1    ford mustang cobra

# %%
df_train[df_train["horsepower"].apply(lambda s:pd.to_numeric(s, errors='coerce')).isnull()].loc[:,"horsepower"]
# Out:
# 25    NaN
# 80    NaN
# 176   NaN
# Name: horsepower, dtype: float64

# %%
df_train["horsepower"] = pd.to_numeric(df_train["horsepower"],errors='coerce')
print(df_train['horsepower'].isnull().sum())
# Out:
# 3

# %%
df_train["horsepower"] = df_train["horsepower"].fillna(hp_mean)
df_train["horsepower"]=df_train["horsepower"].astype("float64")
print(df_train.info())
print(df_train['horsepower'].isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    199 non-null    int64
#  1   mpg           199 non-null    float64
#  2   cylinders     199 non-null    int64
#  3   displacement  199 non-null    float64
#  4   horsepower    199 non-null    float64
#  5   weight        199 non-null    int64
#  6   acceleration  199 non-null    float64
#  7   model year    199 non-null    int64
#  8   origin        199 non-null    int64
#  9   car name      199 non-null    object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 15.7+ KB
# None
# 0

# %%
df_train["mpg"].describe()
# Out:
# count    199.000000
# mean      22.997990
# std        7.693379
# min        9.000000
# 25%       16.000000
# 50%       22.000000
# 75%       28.000000
# max       44.300000
# Name: mpg, dtype: float64

# %%
df_train["mpg"].hist(bins=10)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,10))
df_corr = df_train.drop("car name",axis=1)
df_corr =df_corr.corr()
sns.heatmap(df_corr,vmax=1,vmin=-1,center=0,annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
num_cols = ["cylinders","displacement","horsepower","weight","mpg"]
sns.pairplot(df_train[num_cols],size=2.5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X_train = df_train[num_cols]
y_train = df_train["mpg"]
display(X_train.head())
display(y_train.head())
# Out:
#    cylinders  displacement  horsepower  weight   mpg
# 0          4          85.0        70.0    2070  39.4
# 1          6         171.0        97.0    2984  18.0
# 2          6         168.0       132.0    2910  32.7
# 3          4          89.0        60.0    1968  38.1
# 4          4          98.0        80.0    2164  28.0
# 0    39.4
# 1    18.0
# 2    32.7
# 3    38.1
# 4    28.0
# Name: mpg, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
model.predict(X_train)
# Out:
# array([39.4, 18. , 32.7, 38.1, 28. , 17.5, 15. , 15.5, 15. , 23. , 27.2,
#        18.5, 20.5, 14. , 27.9, 21. , 32.2, 27. , 15.5, 16. , 30.7, 29.5,
#        14. , 21.5, 26. , 40.9, 24. , 16. , 22.3, 18. , 26.6, 18. , 24. ,
#        16. , 27. , 38. , 21. , 13. , 22. , 38. , 37.3, 22. , 16. , 16. ,
#        15. , 44. , 24. , 36. , 31. , 22. , 14. , 22. , 28. , 13. , 16.5,
#        12. , 30. , 20.3, 32.9, 33.5, 13. , 20.5, 19. , 12. , 20. , 26. ,
#        13. , 17. , 25. , 14. , 31. , 14. , 22.4, 24. , 14. , 23.9, 19. ,
#        28.8, 23. , 25.1, 34.5, 24.3, 31. , 31.5, 19.4, 17. ,  9. , 26. ,
#        18.5, 12. , 15. , 18. , 28. , 25. , 34.7, 33. , 14. , 24. , 18. ,
#        37.2, 31.5, 19.4, 21.1, 28. , 18. , 27. , 16.2, 34. , 29.5, 13. ,
#        13. , 26. , 23.9, 14. , 33.7, 27.2, 16.5, 16. , 13. , 24. , 13. ,
#        18.6, 24. , 35. , 27. , 13. , 23. , 23. , 25.4, 17.5, 35.1, 36.1,
#        26. , 13. , 12. , 26. , 30. , 19. , 17.5, 14. , 15.5, 14.5, 16. ,
#        40.8, 18.2, 26. , 17.5, 32. , 23. , 19.8, 20.2, 33.8, 10. , 31. ,
#        16. , 26. , 28.1, 17.6, 13. , 22. , 20.6, 26.5, 13. , 28. , 33.5,
#        24.5, 34.5, 11. , 28. , 21.6, 19.9, 18.5, 15. , 18. , 22. , 27.5,
#        23.6, 34.2, 30.5, 32. , 15. , 20.2, 23.7, 44.3, 14. , 21. , 16. ,
#        28. , 15. , 22. , 14. , 30. , 32.8, 26.4, 27. , 26. , 29. , 31.3,
#        15.5])
